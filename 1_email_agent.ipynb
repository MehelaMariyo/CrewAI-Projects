# %%
from dotenv import load_dotenv
from sympy.physics.units import temperature

load_dotenv()
# Out:
# True

# %%
from crewai import LLM

llm = LLM(
    model="gemini/gemini-3.1-flash-lite-preview",
    temperature=0.1
)

# %%
from crewai.tools import BaseTool

class replaceJargonTool(BaseTool):
    name: str = "Replace Jargon"
    description: str = "Replace jargon with specific terms"

    def _run(self, email:str) -> str:
        replacements = {
            "PRX": "Project Phoenix (internal AI revamp project)",
            "TAS": "technical architecture stack",
            "DBX": "client database cluster",
            "SYNCBOT":"internal standup assistant bot",
            "WIP": "work in progress",
            "POC": "proof of concept",
            "ping": "reach out"
        }

        suggestions =[]
        email_lower = email.lower()
        for jargon, replacement in replacements.items():
            if jargon.lower() in email_lower:
                suggestions.append(f"Consider replacing '{jargon}' with '{replacement}'")

        return "\n".join(suggestions) if suggestions else "No jargon or internal abbreviation detected"

# %%
jt = replaceJargonTool()

# %%
from crewai import Agent, Task, Crew

email_assistant = Agent(
    role = "Email Assistant Agent",
    goal = "Improve emails and make them sound professional and clear",
    backstory = "A highly experienced communication expert skilled in professional email writing",
    verbose = True,
    llm = llm,
    tools=[jt]
)

# %%
original_email = """
hey team, just wanted to tell u that the demo is kind of ready, but there's still stuff left.
Maybe we can show what we have and say rest is WIP.
Let me know what u think, thanks
"""

# %%
original_email_2 = """
Looping in Priya. TAS and PRX updates are in the deck. ETA for SDS integration in Friday.
Let's sync up tomorrow if SYNCBOT allows. ping me if any blockers.
"""

# %%
email_task = Task(
    description=f"""Take following rough email and rewrite it into professional and polished version,
    Expand abbreviations with help of tools.
    '''{original_email_2}'''""",
    agent = email_assistant,
    expected_output="A professional written email with proper formatting and content."
)

# %%
crew = Crew(
    agents=[email_assistant],
    tasks=[email_task],
    verbose=True
)

result = crew.kickoff()
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 56d23e84-3005-494b-8ce6-a26364fcd3fe                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Take following rough email and rewrite it into professional and polished version,                        │
# │      Expand abbreviations with help of tools.                                                                   │
# │      '''                                                                                                        │
# │  Looping in Priya. TAS and PRX updates are in the deck. ETA for SDS integration in Friday.                      │
# │  Let's sync up tomorrow if SYNCBOT allows. ping me if any blockers.                                             │
# │  '''                                                                                                            │
# │  ID: e6701f20-dfe8-4c86-84d4-48346c2e030b                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Email Assistant Agent                                                                                   │
# │                                                                                                                 │
# │  Task: Take following rough email and rewrite it into professional and polished version,                        │
# │      Expand abbreviations with help of tools.                                                                   │
# │      '''                                                                                                        │
# │  Looping in Priya. TAS and PRX updates are in the deck. ETA for SDS integration in Friday.                      │
# │  Let's sync up tomorrow if SYNCBOT allows. ping me if any blockers.                                             │
# │  '''                                                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Email Assistant Agent                                                                                   │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Subject: Update: Technical Architecture Stack and Project Phoenix Status                                       │
# │                                                                                                                 │
# │  Hi Team,                                                                                                       │
# │                                                                                                                 │
# │  I am looping in Priya on this thread.                                                                          │
# │                                                                                                                 │
# │  Please note that the updates regarding the technical architecture stack and Project Phoenix have been added    │
# │  to the deck. The estimated time of arrival for the Software Development System integration is this Friday.     │
# │                                                                                                                 │
# │  Let’s sync up tomorrow, pending availability on the internal standup assistant bot. Please reach out if you    │
# │  encounter any blockers.                                                                                        │
# │                                                                                                                 │
# │  Best regards,                                                                                                  │
# │                                                                                                                 │
# │  [Your Name]                                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Take following rough email and rewrite it into professional and polished version,                        │
# │      Expand abbreviations with help of tools.                                                                   │
# │      '''                                                                                                        │
# │  Looping in Priya. TAS and PRX updates are in the deck. ETA for SDS integration in Friday.                      │
# │  Let's sync up tomorrow if SYNCBOT allows. ping me if any blockers.                                             │
# │  '''                                                                                                            │
# │  Agent: Email Assistant Agent                                                                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 56d23e84-3005-494b-8ce6-a26364fcd3fe                                                                       │
# │  Final Output: Subject: Update: Technical Architecture Stack and Project Phoenix Status                         │
# │                                                                                                                 │
# │  Hi Team,                                                                                                       │
# │                                                                                                                 │
# │  I am looping in Priya on this thread.                                                                          │
# │                                                                                                                 │
# │  Please note that the updates regarding the technical architecture stack and Project Phoenix have been added    │
# │  to the deck. The estimated time of arrival for the Software Development System integration is this Friday.     │
# │                                                                                                                 │
# │  Let’s sync up tomorrow, pending availability on the internal standup assistant bot. Please reach out if you    │
# │  encounter any blockers.                                                                                        │
# │                                                                                                                 │
# │  Best regards,                                                                                                  │
# │                                                                                                                 │
# │  [Your Name]                                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Subject: Update: Technical Architecture Stack and Project Phoenix Status
#
# Hi Team,
#
# I am looping in Priya on this thread.
#
# Please note that the updates regarding the technical architecture stack and Project Phoenix have been added to the deck. The estimated time of arrival for the Software Development System integration is this Friday.
#
# Let’s sync up tomorrow, pending availability on the internal standup assistant bot. Please reach out if you encounter any blockers.
#
# Best regards,
#
# [Your Name]
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
